# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
splat_paths = np.load('./splat_paths.npz')['arr_0']
splat_groups = np.load('splat_groups.npz')['arr_0']

# %%
plt.imshow(splat_paths, cmap='RdBu')

# %%
plt.imshow(splat_groups, cmap='RdBu')

# %%
import graphfit

# %%
knn_result = graphfit.get_knn(splat_paths[0:2])

# %%
knn_result

# %%
gauss_result = graphfit.get_gauss(splat_paths)
